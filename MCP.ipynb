# %% [markdown]
# <a href="https://colab.research.google.com/github/fallensoapbubble/AI-proctoring/blob/main/MCP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
helloz
